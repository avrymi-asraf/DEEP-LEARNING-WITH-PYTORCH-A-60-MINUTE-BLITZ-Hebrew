# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# # יבוא דאטא

# %%
#script to download files 
##!!! only for files that downloaded at `.tar.gz` format


import requests         #for downloading files
import tarfile          #for extracting files
import pathlib          #check if file exists

URL = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
DATA_FOLDER = "data"
DATA_SET = "cifar-10"

data_set_folder = pathlib.Path(f"{DATA_FOLDER}/{DATA_SET}")
downloaded_file =  pathlib.Path(f"{DATA_FOLDER}/{DATA_SET}/{DATA_SET}.tar.gz")

if not data_set_folder.exists():
    data_set_folder.mkdir(exist_ok=True)
    response = requests.get(URL)
    open(downloaded_file, "wb").write(response.content)
if downloaded_file.exists():
    # extracting file
    file = tarfile.open(downloaded_file)
    file.extractall(data_set_folder)
    file.close()
    #delet downloaded file
    if input("do you want to delete the downloaded file?\ny or n") in "Yy":
        downloaded_file.unlink()

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# ### יבוא הקבצים
# נשתמש בספרייה
# `pickle`
# שמאפשרת לטעון אובייקטי פייתון מתוך קבצים.

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='latin1')
    return dict
